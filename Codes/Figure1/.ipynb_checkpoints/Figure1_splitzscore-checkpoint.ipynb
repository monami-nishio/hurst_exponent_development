# %%
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from natsort import natsorted
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib.cm as cm
from pygam import LinearGAM, s, f
from scipy import stats
sns.set(font_scale=1.5, style="white")

# %%
regionname = pd.read_csv('../../Modules/human/schaefer400_regions.csv')
sarank = pd.read_csv('../../Modules/human/Sensorimotor_Association_Axis_AverageRanks.csv')
sarank = pd.concat([regionname.reset_index(drop=True), sarank.reset_index(drop=True)],axis=1)
sarank = sarank.loc[:, ['name', 'finalrank.wholebrain']]

# %%
# project directory
data_dir = '../../Dataset/rna'
# read expression data
gene_columns = pd.read_csv(os.path.join(data_dir, 'columns_metadata.csv'))
gene_rows = pd.read_csv(os.path.join(data_dir, 'rows_metadata.csv'))
gene_columns['id'] = range(1, len(gene_columns) + 1)
expr_matrix = pd.read_csv(os.path.join(data_dir, 'expression_matrix.csv'), header=None)
expr_matrix = expr_matrix.iloc[:, 1:]

# %%
# remove genes without an entrez id
expr_subset = expr_matrix[~gene_rows['entrez_id'].isna()]
rows_subset = gene_rows[~gene_rows['entrez_id'].isna()]

# %%
# log2 transform expression data and collapse duplicated transcripts
log2_expr = np.log2(expr_subset + 1)
log2_expr['entrez_id'] = rows_subset['entrez_id']

# %%
markers  = ['PVALB', 'SST','GAD1', 'GAD2', 'DLX1', 'DLX2'] #PVALB
for marker in markers:
    ids = gene_rows[gene_rows.gene_symbol==marker].entrez_id.values[0]
    df_marker = log2_expr[log2_expr.entrez_id==ids].iloc[:, :-1].T.values
    gene_columns[marker] = df_marker

# %%
sa_cortex = np.unique([x for x in gene_columns.structure_name if 'cortex' in x])
sa_cortex = pd.DataFrame([x for x in sa_cortex if 'cereb' not in x])
sa_cortex.columns = ['structure_name']

# %%
#adults = [ '18 yrs', '19 yrs', '21 yrs','23 yrs', '30 yrs', '36 yrs', '37 yrs', '40 yrs']
adults = [ '18 yrs', '19 yrs', '21 yrs','23 yrs']
cbpd_wide = ['3 yrs','4 yrs', '8 yrs', '11 yrs','13 yrs']

# %%
df = pd.read_csv('../../Dataset/rna/brodmann_schaefer_0.8.csv')

# %%
child_original = pd.read_csv('../../Derivatives/childhood/original.csv')
adult_original = pd.read_csv('../../Derivatives/adult/original.csv')

Visual = [x for x in df.columns if 'BA17' in x]
Auditory = [x for x in df.columns if 'BA41' in x]
Sensory =  [x for x in df.columns if 'BA1_3' in x] + [x for x in df.columns if 'BA2' in x] # [x for x in sarank.name.values if 'S2' in x] +
Motor = [x for x in df.columns if 'BA4' in x]
vPFC = [x for x in df.columns if 'BA44' in x] +  [x for x in df.columns if 'BA45' in x]
dPFC = [x for x in df.columns if 'BA8' in x] + [x for x in df.columns if 'BA9' in x] + [x for x in df.columns if 'BA46' in x]
OFC = [x for x in df.columns if 'BA11' in x] + [x for x in df.columns if 'BA12' in x]+ [x for x in df.columns if 'BA13' in x]  + [x for x in df.columns if 'BA14_' in x]
TEv = [x for x in df.columns if 'BA20' in x]
ACC = [x for x in df.columns if 'BA24' in x] + [x for x in df.columns if 'BA25' in x] + [x for x in df.columns if 'BA32' in x]
STC = [x for x in df.columns if 'BA22' in x]
IPC = [x for x in df.columns if 'BA39' in x] +  [x for x in df.columns if 'BA40' in x]

child_regions = []
adult_regions = []
sas = []
for x in [Sensory, Auditory, Motor, Visual, vPFC, dPFC, OFC, TEv, ACC, STC, IPC]:
    roi  = df.loc[:, x].sum(axis=1)>0
    child_original['roi']=roi
    adult_original['roi']=roi
    child_regions.append(child_original[child_original.roi==True].mean()['H'])
    adult_regions.append(adult_original[adult_original.roi==True].mean()['H'])
    sas.append(child_original[child_original.roi==True].mean()['SArank'])

# %%
child = pd.DataFrame([['Sensory', 'Auditory', 'Motor', 'Visual', 'vPFC', 'dPFC', 'OFC', 'TEv', 'ACC', 'STC', 'IPC'], child_regions, sas]).T.sort_values(2).reset_index(drop=True)
child.columns = ['region', 'H', 'sa']
adult = pd.DataFrame([['Sensory', 'Auditory', 'Motor', 'Visual', 'vPFC', 'dPFC', 'OFC', 'TEv', 'ACC', 'STC', 'IPC'], adult_regions, sas]).T.sort_values(2).reset_index(drop=True)
adult.columns = ['region', 'H', 'sa']

# %%
child['sa'] = [0,1,10,2,8,6,3,4,5,9,7]
adult['sa'] = [0,1,10,2,8,6,3,4,5,9,7]

# %%
brodmann = pd.read_csv('../../Dataset/rna/brodmann.csv')

# %%
#sa_cortex['sa'] = [5,10,9,-1,8,-1,2,6,1,4,-1,3,0,-1,7]
sa_cortex['sa'] = [10,7,9,-1,8,-1,5,4,1,3,-1,2,0,-1,6]
gene_columns = pd.merge(gene_columns, sa_cortex, on='structure_name', how='left')

# %%
wide_age
# Out:
#       sa    donor_name  column_num  donor_id  structure_id   id     PVALB  \
# 0    0.0    H376.IX.50         375     12289         10269  375  1.722205
# 1    0.0    H376.IX.51         344     12841         10269  344  2.679503
# 2    0.0    H376.IX.52         363     12981         10269  363  2.388991
# 3    0.0  H376.VIII.52         319     12836         10269  319 -0.771438
# 4    0.0  H376.VIII.54         328     12980         10269  328  0.078414
# ..   ...           ...         ...       ...           ...  ...       ...
# 95  10.0    H376.IX.50         381     12289         10278  381  0.076260
# 96  10.0    H376.IX.51         355     12841         10278  355 -0.133319
# 97  10.0    H376.IX.52         357     12981         10278  357 -0.480441
# 98  10.0  H376.VIII.54         321     12980         10278  321 -1.860857
# 99  10.0     H376.X.51         382     12831         10278  382 -1.139203
#
#          SST      GAD1      GAD2      DLX1      DLX2     age
# 0  -0.092522  0.641622  0.235844  0.022863 -0.822768  11 yrs
# 1   0.038239  0.944744  0.629203  1.041691 -0.413491   8 yrs
# 2  -0.365143  0.605228  0.866712  0.957345  1.423395   8 yrs
# 3  -1.771170 -2.113324 -2.038897 -2.214582 -1.493656   3 yrs
# 4  -2.153874 -1.569012 -1.445239 -1.056907 -0.990143   3 yrs
# ..       ...       ...       ...       ...       ...     ...
# 95  0.830522  0.585613  0.438605  0.539175  1.152210  11 yrs
# 96  1.651802  0.628577  0.652329  1.079570  0.867080   8 yrs
# 97  0.944474 -0.321380  0.043486 -0.121249 -0.426580   8 yrs
# 98 -1.255054 -2.210022 -1.984736 -1.812725 -0.718358   3 yrs
# 99  0.568450  0.277631  0.343211  0.483568  0.657766  13 yrs
#
# [62 rows x 13 columns]

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
#wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
for x in ['PVALB', 'SST', 'GAD1', 'GAD2', 'DLX1', 'DLX2']:
    wide[x] = stats.zscore(wide[x])
#wide = pd.merge(wide, gene_columns.loc[:, ['donor_id', 'age']], on='donor_id')
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()
    colors = ['Blues', 'Purples', 'Greens']
    for k,sets in enumerate([[0,1],[2,3,4,5]]):
        if k==2:
            my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
        else:
            my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
        figure = plt.figure()
        for i, marker in enumerate([markers[x] for x in sets]):
            yerr = wide_std[marker]
            x = wide_mean['sa']
            y = wide_mean[marker]
            plt.plot(x, y,color=my_palette[i])
            plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
        plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Brain regions')
        if k ==0:
            plt.ylim([-1.5, 1.5])
        else:
            plt.ylim([-1,1])
        plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
        #plt.savefig('../figures/Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
        j +=1

# %%
age = pd.DataFrame(gene_columns.age.unique())
age['rank'] = np.arange(1,age.shape[0]+1)
age.columns = ['age', 'rank']
gene_columns = pd.merge(gene_columns, age, on='age', how='left')

# %%
#adults = [ '18 yrs', '19 yrs', '21 yrs','23 yrs']
cbpd_wide = ['3 yrs','4 yrs', '8 yrs', '11 yrs','13 yrs']

# %%
fignum = ['D', 'G']
colors = ['Blues', 'Purples']
for j,sets in enumerate([[0,1],[2,3,4,5]]):
    if j==2:
        my_palette = {c: sns.color_palette(colors[j], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
    else:
        my_palette = {c: sns.color_palette(colors[j], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
    figure = plt.figure()
    for i, marker in enumerate([markers[x] for x in sets]):
        wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in cbpd_wide], :]
        donor = wide.groupby(['donor_id']).mean().reset_index().sort_values('rank')
        donor = donor.groupby(['rank']).std().reset_index().sort_values('rank')
        wide = wide[wide.sa>-1]
        wide = wide.groupby(['age']).mean().reset_index().sort_values('rank')
        x = wide['rank'].values
        y = stats.zscore(wide[marker].values)
        yerr = donor[marker].values/np.sqrt(2)
        plt.plot(x,y , color=my_palette[i])
        plt.fill_between(x,y+yerr, y-yerr, color=my_palette[i])
        plt.xticks(wide['rank'].values, cbpd_wide, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Age')
    plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
    stats.f_oneway(wide.iloc[0, 5:9], wide.iloc[1, 5:9], wide.iloc[2, 5:9])
    #plt.savefig('../figures/Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')

# %%
fignum = ['D', 'G']
colors = ['Blues', 'Purples']
for j,sets in enumerate([[0,1],[2,3,4,5]]):
    figure = plt.figure()
    if j==2:
        my_palette = {c: sns.color_palette(colors[j], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
    else:
        my_palette = {c: sns.color_palette(colors[j], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
    gene_columns = gene_columns[gene_columns.sa>-1]
    for i, marker in enumerate([markers[x] for x in sets]):
        wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in cbpd_wide], :]
        anova = stats.f_oneway(wide[wide.age==cbpd_wide[0]][marker].values,wide[wide.age==cbpd_wide[1]][marker].values,wide[wide.age==cbpd_wide[2]][marker].values,wide[wide.age==cbpd_wide[3]][marker].values,wide[wide.age==cbpd_wide[4]][marker].values)
        print(anova)
        for x in np.arange(5):
            for y in np.arange(5):
                ttest = stats.ttest_ind(wide[wide.age==cbpd_wide[x]][marker].values,wide[wide.age==cbpd_wide[y]][marker].values)
                print([x,y,ttest])
        donor = wide.groupby(['age']).sem().reset_index().sort_values('rank')
        wide = wide.groupby(['age']).mean().reset_index().sort_values('rank')
        x = wide['rank'].values
        y = stats.zscore(wide[marker].values)
        yerr = donor[marker].values
        plt.plot(x,y , color=my_palette[i])
        plt.fill_between(x,y+yerr, y-yerr, color=my_palette[i])
        plt.xticks(wide['rank'].values, cbpd_wide, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Age')
        plt.ylim([-2.5,2])
    plt.savefig('Fig1'+fignum[j]+'_allregion.eps',  format='eps', bbox_inches='tight')
# Out:
# F_onewayResult(statistic=20.049836374170088, pvalue=2.370719913731956e-10)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-6.494781400172724, pvalue=3.1909393605425414e-06)]
# [0, 2, Ttest_indResult(statistic=-7.79511301840122, pvalue=3.7086935397301844e-09)]
# [0, 3, Ttest_indResult(statistic=-6.602056880756754, pvalue=4.402291270945355e-07)]
# [0, 4, Ttest_indResult(statistic=-4.581668477819941, pvalue=9.372945164693182e-05)]
# [1, 0, Ttest_indResult(statistic=6.494781400172724, pvalue=3.1909393605425414e-06)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=0.6201901304897912, pvalue=0.5421353976866685)]
# [1, 3, Ttest_indResult(statistic=1.7361431627898354, pvalue=0.10811677388465105)]
# [1, 4, Ttest_indResult(statistic=2.840149836658489, pvalue=0.014892570598191145)]
# [2, 0, Ttest_indResult(statistic=7.79511301840122, pvalue=3.7086935397301844e-09)]
# [2, 1, Ttest_indResult(statistic=-0.6201901304897912, pvalue=0.5421353976866685)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=1.2102381760717484, pvalue=0.23630550778246429)]
# [2, 4, Ttest_indResult(statistic=2.7112533022753924, pvalue=0.011321786454455614)]
# [3, 0, Ttest_indResult(statistic=6.602056880756754, pvalue=4.402291270945355e-07)]
# [3, 1, Ttest_indResult(statistic=-1.7361431627898354, pvalue=0.10811677388465105)]
# [3, 2, Ttest_indResult(statistic=-1.2102381760717484, pvalue=0.23630550778246429)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=1.6206217061409214, pvalue=0.12075931378161715)]
# [4, 0, Ttest_indResult(statistic=4.581668477819941, pvalue=9.372945164693182e-05)]
# [4, 1, Ttest_indResult(statistic=-2.840149836658489, pvalue=0.014892570598191145)]
# [4, 2, Ttest_indResult(statistic=-2.7112533022753924, pvalue=0.011321786454455614)]
# [4, 3, Ttest_indResult(statistic=-1.6206217061409214, pvalue=0.12075931378161715)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# F_onewayResult(statistic=86.12420794608119, pvalue=1.7508424593382633e-23)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-11.27501957350936, pvalue=7.367177677382116e-10)]
# [0, 2, Ttest_indResult(statistic=-14.945065834187227, pvalue=9.204269676765488e-17)]
# [0, 3, Ttest_indResult(statistic=-12.11230612078622, pvalue=2.004696631995396e-12)]
# [0, 4, Ttest_indResult(statistic=-9.51084288000157, pvalue=4.117914062761178e-10)]
# [1, 0, Ttest_indResult(statistic=11.27501957350936, pvalue=7.367177677382116e-10)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=1.4382599785778278, pvalue=0.16582533588731746)]
# [1, 3, Ttest_indResult(statistic=6.830431999715637, pvalue=1.82219458216846e-05)]
# [1, 4, Ttest_indResult(statistic=6.924454085737821, pvalue=1.595011183457561e-05)]
# [2, 0, Ttest_indResult(statistic=14.945065834187227, pvalue=9.204269676765488e-17)]
# [2, 1, Ttest_indResult(statistic=-1.4382599785778278, pvalue=0.16582533588731746)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=3.75056359887932, pvalue=0.0008167929767590302)]
# [2, 4, Ttest_indResult(statistic=5.282494470947711, pvalue=1.2816290255680116e-05)]
# [3, 0, Ttest_indResult(statistic=12.11230612078622, pvalue=2.004696631995396e-12)]
# [3, 1, Ttest_indResult(statistic=-6.830431999715637, pvalue=1.82219458216846e-05)]
# [3, 2, Ttest_indResult(statistic=-3.75056359887932, pvalue=0.0008167929767590302)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=2.306151424468727, pvalue=0.03193741657183785)]
# [4, 0, Ttest_indResult(statistic=9.51084288000157, pvalue=4.117914062761178e-10)]
# [4, 1, Ttest_indResult(statistic=-6.924454085737821, pvalue=1.595011183457561e-05)]
# [4, 2, Ttest_indResult(statistic=-5.282494470947711, pvalue=1.2816290255680116e-05)]
# [4, 3, Ttest_indResult(statistic=-2.306151424468727, pvalue=0.03193741657183785)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# F_onewayResult(statistic=193.1392739943843, pvalue=1.9738106486085193e-32)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-8.875047219032412, pvalue=3.4694846750741254e-08)]
# [0, 2, Ttest_indResult(statistic=-23.208878985449054, pvalue=7.66577172215152e-23)]
# [0, 3, Ttest_indResult(statistic=-26.90328089320742, pvalue=4.938241619878867e-21)]
# [0, 4, Ttest_indResult(statistic=-23.76972486774105, pvalue=1.2266794478500598e-19)]
# [1, 0, Ttest_indResult(statistic=8.875047219032412, pvalue=3.4694846750741254e-08)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=-2.354962027300155, pvalue=0.0288501280348278)]
# [1, 3, Ttest_indResult(statistic=-2.582828806676156, pvalue=0.023972525186890175)]
# [1, 4, Ttest_indResult(statistic=-1.9043659465028469, pvalue=0.08110904824289725)]
# [2, 0, Ttest_indResult(statistic=23.208878985449054, pvalue=7.66577172215152e-23)]
# [2, 1, Ttest_indResult(statistic=2.354962027300155, pvalue=0.0288501280348278)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=0.6184467704509844, pvalue=0.5412796368393735)]
# [2, 4, Ttest_indResult(statistic=1.39151091966788, pvalue=0.17502802724611344)]
# [3, 0, Ttest_indResult(statistic=26.90328089320742, pvalue=4.938241619878867e-21)]
# [3, 1, Ttest_indResult(statistic=2.582828806676156, pvalue=0.023972525186890175)]
# [3, 2, Ttest_indResult(statistic=-0.6184467704509844, pvalue=0.5412796368393735)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=1.192697325928733, pvalue=0.24694652440563622)]
# [4, 0, Ttest_indResult(statistic=23.76972486774105, pvalue=1.2266794478500598e-19)]
# [4, 1, Ttest_indResult(statistic=1.9043659465028469, pvalue=0.08110904824289725)]
# [4, 2, Ttest_indResult(statistic=-1.39151091966788, pvalue=0.17502802724611344)]
# [4, 3, Ttest_indResult(statistic=-1.192697325928733, pvalue=0.24694652440563622)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# F_onewayResult(statistic=138.3082304875259, pvalue=1.214944319821436e-28)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-6.928301112948503, pvalue=1.3236317517678241e-06)]
# [0, 2, Ttest_indResult(statistic=-18.840889527536586, pvalue=6.668690742842968e-20)]
# [0, 3, Ttest_indResult(statistic=-20.838998636552304, pvalue=3.585111411089323e-18)]
# [0, 4, Ttest_indResult(statistic=-21.366659198445525, pvalue=1.894426712168379e-18)]
# [1, 0, Ttest_indResult(statistic=6.928301112948503, pvalue=1.3236317517678241e-06)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=-3.2583600501241206, pvalue=0.0039346175570600704)]
# [1, 3, Ttest_indResult(statistic=-3.1876701048457323, pvalue=0.00780921629792265)]
# [1, 4, Ttest_indResult(statistic=-3.7085930983249003, pvalue=0.0029884803435712135)]
# [2, 0, Ttest_indResult(statistic=18.840889527536586, pvalue=6.668690742842968e-20)]
# [2, 1, Ttest_indResult(statistic=3.2583600501241206, pvalue=0.0039346175570600704)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=2.7008506360049997, pvalue=0.011605071453141541)]
# [2, 4, Ttest_indResult(statistic=1.5826520008472644, pvalue=0.12473217776639939)]
# [3, 0, Ttest_indResult(statistic=20.838998636552304, pvalue=3.585111411089323e-18)]
# [3, 1, Ttest_indResult(statistic=3.1876701048457323, pvalue=0.00780921629792265)]
# [3, 2, Ttest_indResult(statistic=-2.7008506360049997, pvalue=0.011605071453141541)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=-2.01986311539404, pvalue=0.05699768098844364)]
# [4, 0, Ttest_indResult(statistic=21.366659198445525, pvalue=1.894426712168379e-18)]
# [4, 1, Ttest_indResult(statistic=3.7085930983249003, pvalue=0.0029884803435712135)]
# [4, 2, Ttest_indResult(statistic=-1.5826520008472644, pvalue=0.12473217776639939)]
# [4, 3, Ttest_indResult(statistic=2.01986311539404, pvalue=0.05699768098844364)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# F_onewayResult(statistic=74.90472494308264, pvalue=5.030229826692437e-22)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-5.447575173717047, pvalue=2.9548421867778533e-05)]
# [0, 2, Ttest_indResult(statistic=-16.97657647732718, pvalue=1.8014517548574893e-18)]
# [0, 3, Ttest_indResult(statistic=-10.19226317827654, pvalue=9.421377040163166e-11)]
# [0, 4, Ttest_indResult(statistic=-11.901320804138267, pvalue=2.99712667201035e-12)]
# [1, 0, Ttest_indResult(statistic=5.447575173717047, pvalue=2.9548421867778533e-05)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=-2.0383666579250455, pvalue=0.05495525327333662)]
# [1, 3, Ttest_indResult(statistic=0.24123122343111314, pvalue=0.8134485084023093)]
# [1, 4, Ttest_indResult(statistic=-0.01403008296248217, pvalue=0.989036544697342)]
# [2, 0, Ttest_indResult(statistic=16.97657647732718, pvalue=1.8014517548574893e-18)]
# [2, 1, Ttest_indResult(statistic=2.0383666579250455, pvalue=0.05495525327333662)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=4.544979391028437, pvalue=9.612423982924188e-05)]
# [2, 4, Ttest_indResult(statistic=4.416857793602732, pvalue=0.00013623950487679886)]
# [3, 0, Ttest_indResult(statistic=10.19226317827654, pvalue=9.421377040163166e-11)]
# [3, 1, Ttest_indResult(statistic=-0.24123122343111314, pvalue=0.8134485084023093)]
# [3, 2, Ttest_indResult(statistic=-4.544979391028437, pvalue=9.612423982924188e-05)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=-0.5948218663146217, pvalue=0.5586328232920696)]
# [4, 0, Ttest_indResult(statistic=11.901320804138267, pvalue=2.99712667201035e-12)]
# [4, 1, Ttest_indResult(statistic=0.01403008296248217, pvalue=0.989036544697342)]
# [4, 2, Ttest_indResult(statistic=-4.416857793602732, pvalue=0.00013623950487679886)]
# [4, 3, Ttest_indResult(statistic=0.5948218663146217, pvalue=0.5586328232920696)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# F_onewayResult(statistic=10.955303784545277, pvalue=1.1692223059501868e-06)
# [0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [0, 1, Ttest_indResult(statistic=-2.8966784233712213, pvalue=0.00924591601385667)]
# [0, 2, Ttest_indResult(statistic=-5.776958244623753, pvalue=1.5193286291254284e-06)]
# [0, 3, Ttest_indResult(statistic=-3.772188823407964, pvalue=0.0008060348093819035)]
# [0, 4, Ttest_indResult(statistic=-8.023347368834516, pvalue=1.2720636743398149e-08)]
# [1, 0, Ttest_indResult(statistic=2.8966784233712213, pvalue=0.00924591601385667)]
# [1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [1, 2, Ttest_indResult(statistic=-1.0241101197835343, pvalue=0.318011494153071)]
# [1, 3, Ttest_indResult(statistic=0.24003533686643122, pvalue=0.8143542488790249)]
# [1, 4, Ttest_indResult(statistic=-1.2179777635847724, pvalue=0.24663923800765744)]
# [2, 0, Ttest_indResult(statistic=5.776958244623753, pvalue=1.5193286291254284e-06)]
# [2, 1, Ttest_indResult(statistic=1.0241101197835343, pvalue=0.318011494153071)]
# [2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [2, 3, Ttest_indResult(statistic=2.1922890896851657, pvalue=0.03683413674342303)]
# [2, 4, Ttest_indResult(statistic=0.5125768442973825, pvalue=0.612267466886236)]
# [3, 0, Ttest_indResult(statistic=3.772188823407964, pvalue=0.0008060348093819035)]
# [3, 1, Ttest_indResult(statistic=-0.24003533686643122, pvalue=0.8143542488790249)]
# [3, 2, Ttest_indResult(statistic=-2.1922890896851657, pvalue=0.03683413674342303)]
# [3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0)]
# [3, 4, Ttest_indResult(statistic=-2.3277109325083365, pvalue=0.03053796336269878)]
# [4, 0, Ttest_indResult(statistic=8.023347368834516, pvalue=1.2720636743398149e-08)]
# [4, 1, Ttest_indResult(statistic=1.2179777635847724, pvalue=0.24663923800765744)]
# [4, 2, Ttest_indResult(statistic=-0.5125768442973825, pvalue=0.612267466886236)]
# [4, 3, Ttest_indResult(statistic=2.3277109325083365, pvalue=0.03053796336269878)]
# [4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0)]
