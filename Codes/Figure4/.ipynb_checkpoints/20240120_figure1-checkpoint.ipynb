# %%
from nilearn.maskers import NiftiMasker, NiftiLabelsMasker
from nilearn.image import load_img
from nilearn.connectome import ConnectivityMeasure
from nilearn import plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nilearn import datasets, image
from nilearn.maskers import NiftiMasker, NiftiLabelsMasker
from nilearn.image import load_img
from nilearn.surface import vol_to_surf, load_surf_mesh
from nilearn.connectome import ConnectivityMeasure
from nilearn import plotting
import seaborn as sns
from nilearn import datasets, image
from scipy import stats
import nibabel as nib
import statsmodels.api as sm
import glob
import os
from pygam import LinearGAM, s, f, GAM
from sklearn.linear_model import LinearRegression
import seaborn as sns
from statsmodels.stats.multitest  import fdrcorrection
from enigmatoolbox.permutation_testing import spin_test, shuf_test

# %%
anatomical = pd.read_csv('../../Modules/Figure4/SIGMA_InVivo_Anatomical_Brain_Atlas_Labels.txt', sep='\t')
anatmap = pd.read_csv('../../Modules/Figure4/SIGMA_InVivo_Anatomical_Brain_Atlas_ListOfStructures.csv')
left_anatmap = anatmap.loc[:, ['Left Hemisphere Label', 'Matter', 'Territories', 'System', 'Region of interest']] 
right_anatmap = anatmap.loc[:, ['Right Hemisphere Label', 'Matter', 'Territories', 'System', 'Region of interest']]
left_anatmap.columns = ['Label', 'Matter', 'Territories', 'System', 'Region of interest']
right_anatmap.columns = ['Label', 'Matter', 'Territories', 'System', 'Region of interest']
anatmap = pd.concat([left_anatmap, right_anatmap])
anatomical = pd.merge(anatomical, anatmap, left_on='0', right_on='Label')
anatomical = anatomical.sort_values('Label').reset_index(drop=True)
anatomical = anatomical[anatomical.System!='CSF']
age = pd.read_csv('../../Modules/Figure4/standardRat_20220408.tsv', sep='\t')
H_anat = pd.read_csv('../../Derivatives/Figure4/H.csv')
H_anat = H_anat.iloc[:, :232]

# %%
regions = ['Primary Visual Cortex', 'Primary Auditory Cortex',
           'Lateral Primary Auditory Cortex',  'Primary Somatosensory Cortex Barrel field', 'Primary Somatosensory Cortex Hindlimb',
           'Primary Somatosensory Cortex Jaw', 'Primary Somatosensory Cortex Forelimb', 'Primary Somatosensory Cortex Trunk', 'Secondary Somatosensory Cortex', 
           'Primary Motor Cortex', 'Secondary Motor Cortex', 'Lateral Parietal Associative Cortex', 'Medial Parietal Associative Cortex', 'PreLimbic System','Orbitofrontal Region',
           'Dorso Lateral Orbital Cortex', 'Temporal Associative Cortex', 'Primary Cingular Cortex',  'Retrosplenial Granular Cortex Part A',
           'Retrosplenial Granular Cortex Part B', 'Perirhinal Cortex', 'Entorhinal Cortex']
group = ['Visual','Auditory','Auditory','S1','S1','S1','S1','S1','S2','Motor','Motor','Parietal','Parietal','PL','OFC','OFC', 'IT','ACC','Retro','Retro',
         'Peri','Entr']

# %%
saaxis = pd.DataFrame(np.unique(group))
saaxis.columns = ['region']
saaxis['sa']  = [10,2,13,9,7,8,12,6,11,5,3,4,1]
sa = []
for x in anatomical['Region of interest']:
    ids = 0
    for i,y in enumerate(regions):
        if x == y:
            sa.append(saaxis[saaxis.region==group[i]].sa.values[0])
            ids += 1
    if ids == 0:
        sa.append(-1)

# %%
H_anat['SubjID'] = [x.replace('_t','') for x in H_anat['H_all233']]
H_anat = pd.merge(H_anat, age, on='SubjID')
Age = H_anat.Age
Sex = H_anat.Sex

# %%
H_anat = H_anat.iloc[:, :232].T
H_anat['sa'] = sa
H_anat = H_anat[H_anat.sa>-1]

# %%
df_H = H_anat.sort_values('sa').T.iloc[:-1, :]

# %%
df_H['Age'] = Age
df_H['Sex'] =Sex
df_H = df_H[df_H.Age>0]
df_H = df_H[df_H.Age<4].reset_index(drop=True)
df_H.to_csv('H_age.csv', index=False)

# %%
df_H = H_anat.sort_values('sa').groupby('sa').mean().reset_index().T.iloc[1:,:]
df_H['Age'] = Age
df_H['Sex'] =Sex
df_H = df_H[df_H.Age>0]
df_H = df_H[df_H.Age<4].reset_index(drop=True)
df_H.to_csv('H_age_mean.csv', index=False)
H_anat.sort_values('sa').sa.to_csv('sa.csv', index=False)

# %%
regions_id = []
for i, x in enumerate(anatomical['Region of interest']):
    if x in regions:
        regions_id.append(i)

# %%
df_ind = pd.DataFrame(anatomical['Region of interest'].values)
df_ind.columns = ['Region of interest']
df_ind['roi'] = np.zeros(df_ind.shape[0])
for j,region in enumerate(regions):
    reind = []
    for x in anatomical['Region of interest'].unique():
        if region in x:
            df_ind.loc[df_ind['Region of interest']==x, 'roi'] = j+1

# %%
H_anat = H_anat.iloc[:, regions_id]

# %%
anatomical = anatomical.iloc[regions_id, :].reset_index(drop=True)

# %%
anatomical['H'] = H_anat.mean().values
anatomical['Hsd'] = H_anat.sem().values

# %%
df = pd.DataFrame()
groups = []
for x,y in zip(regions,group):
    df = pd.concat([df, anatomical[anatomical['Region of interest']==x]])
    print([x, anatomical[anatomical['Region of interest']==x].shape])
    groups += list(np.repeat(y, anatomical[anatomical['Region of interest']==x].shape[0]))
df = df.reset_index(drop=True)
df['group'] = groups
# Out:
# ['Primary Visual Cortex', (2, 15)]
# ['Primary Auditory Cortex', (2, 15)]
# ['Lateral Primary Auditory Cortex', (2, 15)]
# ['Primary Somatosensory Cortex Barrel field', (2, 15)]
# ['Primary Somatosensory Cortex Hindlimb', (2, 15)]
# ['Primary Somatosensory Cortex Jaw', (2, 15)]
# ['Primary Somatosensory Cortex Forelimb', (2, 15)]
# ['Primary Somatosensory Cortex Trunk', (2, 15)]
# ['Secondary Somatosensory Cortex', (2, 15)]
# ['Primary Motor Cortex', (2, 15)]
# ['Secondary Motor Cortex', (2, 15)]
# ['Lateral Parietal Associative Cortex', (2, 15)]
# ['Medial Parietal Associative Cortex', (2, 15)]
# ['PreLimbic System', (2, 15)]
# ['Orbitofrontal Region', (2, 15)]
# ['Dorso Lateral Orbital Cortex', (2, 15)]
# ['Temporal Associative Cortex', (2, 15)]
# ['Primary Cingular Cortex', (2, 15)]
# ['Retrosplenial Granular Cortex Part A', (2, 15)]
# ['Retrosplenial Granular Cortex Part B', (2, 15)]
# ['Perirhinal Cortex', (2, 15)]
# ['Entorhinal Cortex', (2, 15)]
# (44, 15)

# %%
rank = ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'IT',  'ACC','Peri','PL','Entr']
my_palette = {c: sns.color_palette('Blues', n_colors=(3)).as_hex()[c+1] for c in np.arange(2)}
df_mean = df.groupby('group').mean().reset_index()
df_std = df.groupby('group').sem().reset_index()
m = [df_mean[df_mean.group==x]['H'].values[0] for x in rank]
s = [df_std[df_std.group==x]['H'].values[0] for x in rank]
plt.plot(rank, m, '--', color='k')
plt.fill_between(rank, [x+y for x,y in zip(m,s)], [x-y for x,y in zip(m,s)], alpha=0.15,color='k') 
plt.xticks(rotation=90)
plt.ylim([1.565, 1.595])
plt.savefig('../figures/Fig1F.eps',  format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
mmc1 = pd.read_csv('../modules/mmc1.csv', header=1)
mmc3 = pd.read_csv('../modules/mmc3.csv', header=1)
mmc1 = mmc1[mmc1['Average']!=' N/D ']
mmc1 = mmc1[mmc1['Average.1']!=' N/D ']
mmc3 = mmc3[mmc3[' mean ']!=' N/D ']
mmc3 = mmc3[mmc3[' mean .2']!=' N/D ']
mmc3 = mmc3[mmc3[' mean ']!=' - ']
mmc3 = mmc3[mmc3[' mean .2']!=' - ']
mmc1 = mmc1[mmc1['standard deviation']!=' N/D ']
mmc1 = mmc1[mmc1['standard deviation.1']!=' N/D ']
mmc3 = mmc3[mmc3[' SD ']!=' N/D ']
mmc3 = mmc3[mmc3[' SD .2']!=' N/D ']
mmc3 = mmc3[mmc3[' SD ']!=' - ']
mmc3 = mmc3[mmc3[' SD .2']!=' - ']
mmc1['PVmean'] = [int(x.replace(',', '')) for x in mmc1['Average']]
mmc1['SSTmean'] = [int(x.replace(',', '')) for x in mmc1['Average.1']]
mmc3['PVmean'] = [int(x.replace(',', '')) for x in mmc3[' mean ']]
mmc3['SSTmean'] = [int(x.replace(',', '')) for x in mmc3[' mean .2']]
mmc1['PVsd'] = [int(x.replace(',', '')) for x in mmc1['standard deviation']]
mmc1['SSTsd'] = [int(x.replace(',', '')) for x in mmc1['standard deviation.1']]
mmc3['PVsd'] = [int(x.replace(',', '')) for x in mmc3[' SD ']]
mmc3['SSTsd'] = [int(x.replace(',', '')) for x in mmc3[' SD .2']]
areas = ['Primary visual area','Primary auditory area','Primary somatosensory area, barrel field','Primary somatosensory area, lower limb','Primary somatosensory area, mouth',
         'Primary somatosensory area, upper limb','Primary somatosensory area, trunk','Supplemental somatosensory area','Primary motor area',
         'Posterior parietal association areas','Prelimbic area','Orbital area, medial part','Orbital area, lateral part','Orbital area, ventrolateral part','Temporal association areas',
         'Anterior cingulate area, dorsal part','Anterior cingulate area, ventral part','Retrosplenial area, dorsal part','Retrosplenial area, ventral part','Perirhinal area','Ectorhinal area']
group = ['Visual','Auditory','S1','S1','S1','S1','S1','S2','Motor','Parietal','PL','OFC','OFC','OFC','IT','ACC','ACC','Retro', 
         'Retro','Peri','Entr'] #'Visual','Visual','Visual','Visual', #'Posterolateral visual area', 'Anterolateral visual area','Anteromedial visual area','posteromedial visual area',
df_t = pd.DataFrame()
for x in areas:
    df_t = pd.concat([df_t, mmc3[mmc3['Full name']==x]])
df_t = df_t.reset_index(drop=True)
my_palette = {c: sns.color_palette('Blues', n_colors=(3)).as_hex()[c+1] for c in np.arange(2)}
plt.plot(df_t.PVmean.values,color=my_palette[0]) 
plt.fill_between(df_t.ROI, df_t.PVmean+df_t.PVsd, df_t.PVmean-df_t.PVsd, alpha=0.15,color=my_palette[0]) 
plt.plot(df_t.SSTmean.values,color=my_palette[1]) 
plt.fill_between(df_t.ROI, df_t.SSTmean+df_t.SSTsd, df_t.SSTmean-df_t.SSTsd, alpha=0.15,color=my_palette[1]) 
plt.xticks(rotation=90)
expression = df_t
expression['group'] = group

# %%
df_concat = pd.merge(df.groupby('group').mean().reset_index(), expression.groupby('group').mean().reset_index(), on='group', how='inner')
df_concat_std = pd.merge(df.groupby('group').std().reset_index(), expression.groupby('group').std().reset_index(), on='group', how='inner')

# %%
df_concat['inhibitory'] = df_concat.PVmean+df_concat.SSTmean
df_concat = df_concat_copy
figure = plt.figure()
for i in [x for x in np.arange(df_concat.shape[0])]:
    plt.scatter(df_concat.PVmean[i]+df_concat.SSTmean[i], df_concat['H'][i])
df_x = pd.DataFrame(df_concat.PVmean+df_concat.SSTmean)
df_y = pd.DataFrame(df_concat['H'])
mod = LinearRegression()
mod_lin = mod.fit(df_x, df_y)
y_lin_fit = mod_lin.predict(df_x)
r2_lin = mod.score(df_x, df_y)
plt.plot(df_x, y_lin_fit, color = '#000000', linewidth=2)
print(r2_lin)
X = sm.add_constant(df_concat.PVmean+df_concat.SSTmean)
results = sm.OLS(df_concat['H'],X).fit()
print(results.summary())
plt.savefig('../figures/Fig3E.eps',  format='eps')
plt.legend(df_concat.group)
# Out:
# 0.3122075161717648
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      H   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     4.993
# Date:                Mon, 29 Jan 2024   Prob (F-statistic):             0.0471
# Time:                        11:08:16   Log-Likelihood:                 54.182
# No. Observations:                  13   AIC:                            -104.4
# Df Residuals:                      11   BIC:                            -103.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5657      0.007    212.535      0.000       1.550       1.582
# 0           1.881e-06   8.42e-07      2.235      0.047    2.82e-08    3.73e-06
# ==============================================================================
# Omnibus:                        0.455   Durbin-Watson:                   1.352
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.214
# Skew:                          -0.279   Prob(JB):                        0.899
# Kurtosis:                       2.712   Cond. No.                     5.71e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.71e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/monaminishio/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
figure = plt.figure()
plt.scatter(df_concat.PVmean-df_concat.SSTmean, df_concat['H'])
df_x = pd.DataFrame(df_concat.PVmean-df_concat.SSTmean)
df_y = pd.DataFrame(df_concat['H'])
mod = LinearRegression()
mod_lin = mod.fit(df_x, df_y)
y_lin_fit = mod_lin.predict(df_x)
r2_lin = mod.score(df_x, df_y)
plt.plot(df_x, y_lin_fit, color = '#000000', linewidth=2)
print(r2_lin)
X = sm.add_constant(df_concat.PVmean-df_concat.SSTmean)
results = sm.OLS(df_concat['H'],X).fit()
print(results.summary())
plt.savefig('../figures/Fig3E.eps',  format='eps')
# Out:
# 0.39921642218104103
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      H   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     7.309
# Date:                Sun, 21 Jan 2024   Prob (F-statistic):             0.0205
# Time:                        12:01:08   Log-Likelihood:                 55.061
# No. Observations:                  13   AIC:                            -106.1
# Df Residuals:                      11   BIC:                            -105.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5839      0.001   1243.672      0.000       1.581       1.587
# 0           1.701e-06   6.29e-07      2.704      0.021    3.16e-07    3.09e-06
# ==============================================================================
# Omnibus:                        4.126   Durbin-Watson:                   1.327
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                2.235
# Skew:                          -1.015   Prob(JB):                        0.327
# Kurtosis:                       3.068   Cond. No.                     2.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/monaminishio/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
figure = plt.figure()
plt.plot(stats.zscore(df_concat.PVmean.values))
plt.savefig('../figures/Fig3F.eps',  format='eps')
plt.plot(stats.zscore(df_concat.H.values), '--')
plt.savefig('../figures/Fig3F.eps',  format='eps')

# %%
plt.plot([df_concat[df_concat.group==x].PVmean.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT', 'Peri','PL','Entr']],color=my_palette[0])
means = [df_concat[df_concat.group==x].PVmean.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT', 'Peri','PL','Entr']]
sds = [df_concat[df_concat.group==x].PVsd.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT', 'Peri','PL','Entr']]
plt.fill_between(np.arange(13), [x+y for x,y in zip(means,sds)],  [x-y for x,y in zip(means,sds)], alpha=0.15,color=my_palette[0]) 
plt.plot([df_concat[df_concat.group==x].SSTmean.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC',  'ACC','IT', 'Peri','PL','Entr']],color=my_palette[1])
means = [df_concat[df_concat.group==x].SSTmean.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT', 'Peri','PL','Entr']]
sds = [df_concat[df_concat.group==x].SSTsd.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT', 'Peri','PL','Entr']]
plt.fill_between(np.arange(13), [x+y for x,y in zip(means,sds)],  [x-y for x,y in zip(means,sds)], alpha=0.15,color=my_palette[1]) 
plt.xticks(np.arange(len(['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'IT',  'ACC','Peri','PL','Entr'])), ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT',  'Peri','PL','Entr'], rotation=90)
plt.savefig('../figures/Fig1D.eps',  format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.plot([df_concat[df_concat.group==x].H.values[0] for x in ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC',  'ACC','IT', 'Peri','PL','Entr']], '--', color='k')
plt.xticks(np.arange(len(['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'IT',  'ACC','Peri','PL','Entr'])), ['Visual','Auditory','S1','S2','Retro','Parietal','Motor','OFC', 'ACC','IT',  'Peri','PL','Entr'], rotation=90)
plt.savefig('../figures/Fig1E.eps',  format='eps', bbox_inches='tight')
