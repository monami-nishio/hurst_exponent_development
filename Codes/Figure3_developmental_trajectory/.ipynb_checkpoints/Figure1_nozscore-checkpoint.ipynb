# %%
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from natsort import natsorted
from scipy.stats import pearsonr
import seaborn as sns
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.cm as cm
from pygam import LinearGAM, s, f
from scipy import stats
sns.set(font_scale=1.5, style="white")

# %%
regionname = pd.read_csv('../../Modules/human/schaefer400_regions.csv')
sarank = pd.read_csv('../../Modules/human/Sensorimotor_Association_Axis_AverageRanks.csv')
sarank = pd.concat([regionname.reset_index(drop=True), sarank.reset_index(drop=True)],axis=1)
sarank = sarank.loc[:, ['name', 'finalrank.wholebrain']]

# %%
# project directory
data_dir = '../../Dataset/rna'
# read expression data
gene_columns = pd.read_csv(os.path.join(data_dir, 'columns_metadata.csv'))
gene_rows = pd.read_csv(os.path.join(data_dir, 'rows_metadata.csv'))
gene_columns['id'] = range(1, len(gene_columns) + 1)
expr_matrix = pd.read_csv(os.path.join(data_dir, 'expression_matrix.csv'), header=None)
expr_matrix = expr_matrix.iloc[:, 1:]

# %%
# remove genes without an entrez id
expr_subset = expr_matrix[~gene_rows['entrez_id'].isna()]
rows_subset = gene_rows[~gene_rows['entrez_id'].isna()]

# %%
# log2 transform expression data and collapse duplicated transcripts
log2_expr = np.log2(expr_subset + 1)
log2_expr['entrez_id'] = rows_subset['entrez_id']

# %%
markers  = ['PVALB', 'SST',  'GAD1', 'GAD2', 'DLX1', 'GABARAP', 'VIP'] #PVALB
for marker in markers:
    ids = gene_rows[gene_rows.gene_symbol==marker].entrez_id.values[0]
    df_marker = log2_expr[log2_expr.entrez_id==ids].iloc[:, :-1].T.values
    gene_columns[marker] = df_marker

# %%
sa_cortex = np.unique([x for x in gene_columns.structure_name if 'cortex' in x])
sa_cortex = pd.DataFrame([x for x in sa_cortex if 'cereb' not in x])
sa_cortex.columns = ['structure_name']

# %%
#adults = [ '18 yrs', '19 yrs', '21 yrs','23 yrs', '30 yrs', '36 yrs', '37 yrs', '40 yrs']
adults = [ '18 yrs', '19 yrs', '21 yrs','23 yrs']#, '30 yrs', '36 yrs', '37 yrs', '40 yrs']
cbpd_wide = ['3 yrs','4 yrs', '8 yrs', '11 yrs','13 yrs']

# %%
df = pd.read_csv('../../Dataset/rna/brodmann_schaefer_0.8.csv')

# %%
child_original = pd.read_csv('../../Derivatives/childhood/original.csv')
adult_original = pd.read_csv('../../Derivatives/adult/original.csv')

Visual = [x for x in df.columns if 'BA17' in x]
Auditory = [x for x in df.columns if 'BA41' in x]
Sensory =  [x for x in df.columns if 'BA1_3' in x] + [x for x in df.columns if 'BA2' in x] # [x for x in sarank.name.values if 'S2' in x] +
Motor = [x for x in df.columns if 'BA4' in x]
vPFC = [x for x in df.columns if 'BA44' in x] +  [x for x in df.columns if 'BA45' in x]
dPFC = [x for x in df.columns if 'BA8' in x] + [x for x in df.columns if 'BA9' in x] + [x for x in df.columns if 'BA46' in x]
OFC = [x for x in df.columns if 'BA11' in x] + [x for x in df.columns if 'BA12' in x]+ [x for x in df.columns if 'BA13' in x]  + [x for x in df.columns if 'BA14_' in x]
TEv = [x for x in df.columns if 'BA20' in x]
ACC = [x for x in df.columns if 'BA24' in x] + [x for x in df.columns if 'BA25' in x] + [x for x in df.columns if 'BA32' in x]
STC = [x for x in df.columns if 'BA22' in x]
IPC = [x for x in df.columns if 'BA39' in x] +  [x for x in df.columns if 'BA40' in x]

child_regions = []
adult_regions = []
sas = []
for x in [Sensory, Auditory, Motor, Visual, vPFC, dPFC, OFC, TEv, ACC, STC, IPC]:
    roi  = df.loc[:, x].sum(axis=1)>0
    child_original['roi']=roi
    adult_original['roi']=roi
    child_regions.append(child_original[child_original.roi==True].mean()['H'])
    adult_regions.append(adult_original[adult_original.roi==True].mean()['H'])
    sas.append(child_original[child_original.roi==True].mean()['SArank'])

# %%
child = pd.DataFrame([['Sensory', 'Auditory', 'Motor', 'Visual', 'vPFC', 'dPFC', 'OFC', 'TEv', 'ACC', 'STC', 'IPC'], child_regions, sas]).T.sort_values(2).reset_index(drop=True)
child.columns = ['region', 'H', 'sa']
adult = pd.DataFrame([['Sensory', 'Auditory', 'Motor', 'Visual', 'vPFC', 'dPFC', 'OFC', 'TEv', 'ACC', 'STC', 'IPC'], adult_regions, sas]).T.sort_values(2).reset_index(drop=True)
adult.columns = ['region', 'H', 'sa']

# %%
child['sa'] = [0,1,10,2,8,6,3,4,5,9,7]
adult['sa'] = [0,1,10,2,8,6,3,4,5,9,7]

# %%
brodmann = pd.read_csv('../../Dataset/rna/brodmann.csv')

# %%
#sa_cortex['sa'] = [5,10,9,-1,8,-1,2,6,1,4,-1,3,0,-1,7]
sa_cortex['sa'] = [10,7,9,-1,8,-1,5,4,1,3,-1,2,0,-1,6]
gene_columns = pd.merge(gene_columns, sa_cortex, on='structure_name', how='left')

# %%
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults], :]
wide = wide[wide.sa>-1].sort_values('sa')
print(wide.shape)
wide.groupby('donor_id').count()
# Out:
# (42, 17)
#           column_num  donor_name  age  gender  structure_id  \
# donor_id
# 12300              9           9    9       9             9
# 12832             11          11   11      11            11
# 12984             11          11   11      11            11
# 13057             11          11   11      11            11
#
#           structure_acronym  structure_name  id  PVALB  SST  GAD1  GAD2  DLX1  \
# donor_id
# 12300                     9               9   9      9    9     9     9     9
# 12832                    11              11  11     11   11    11    11    11
# 12984                    11              11  11     11   11    11    11    11
# 13057                    11              11  11     11   11    11    11    11
#
#           GABARAP  VIP  sa
# donor_id
# 12300           9    9   9
# 12832          11   11  11
# 12984          11   11  11
# 13057          11   11  11

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    for x in ['PVALB', 'SST', 'GAD1', 'GAD2', 'DLX1', 'GABARAP', 'VIP']:
        wide_age[x] = stats.zscore(wide_age[x])
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()/2
    colors = ['Blues', 'Purples', 'Greens']
    for k,sets in enumerate([[0,1],[2,3,4,5],[6]]):
        if k==2:
            my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
        else:
            my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
        figure = plt.figure()
        for i, marker in enumerate([markers[x] for x in sets]):
            yerr = wide_std[marker]
            x = wide_mean['sa']
            y = wide_mean[marker]
            plt.plot(x, y,color=my_palette[i])
            plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
        plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Brain regions')
        if k ==0:
            plt.ylim([-1.5, 1.5])
        else:
            plt.ylim([-1,1.5])
        plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
        #plt.savefig('Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
        j +=1

# %%
age = pd.DataFrame(gene_columns.age.unique())
age['rank'] = np.arange(1,age.shape[0]+1)
age.columns = ['age', 'rank']
gene_columns = pd.merge(gene_columns, age, on='age', how='left')
cbpd_wide = ['3 yrs','4 yrs', '8 yrs', '11 yrs','13 yrs']
fignum = ['D', 'G']
colors = ['Blues', 'Purples', 'Purples']
for j,sets in enumerate([[0,1],[2,3,4,5],[6]]):
    figure = plt.figure()
    if j==2:
        my_palette = {c: sns.color_palette(colors[j], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
    else:
        my_palette = {c: sns.color_palette(colors[j], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
    gene_columns = gene_columns[gene_columns.sa>-1]
    for i, marker in enumerate([markers[x] for x in sets]):
        wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in cbpd_wide], :]
        anova = stats.f_oneway(wide[wide.age==cbpd_wide[0]][marker].values,wide[wide.age==cbpd_wide[1]][marker].values,wide[wide.age==cbpd_wide[2]][marker].values,wide[wide.age==cbpd_wide[3]][marker].values,wide[wide.age==cbpd_wide[4]][marker].values)
        tuckey = pairwise_tukeyhsd(wide[marker], wide.age)
        print(tuckey)
        donor = wide.groupby(['age']).std().reset_index().sort_values('rank')
        wide = wide.groupby(['age']).mean().reset_index().sort_values('rank')
        x = wide['rank'].values
        #y = stats.zscore(wide[marker].values
        y = wide[marker].values
        yerr = donor[marker].values/2
        plt.plot(x,y , color=my_palette[i])
        plt.fill_between(x,y+yerr, y-yerr, color=my_palette[i])
        plt.xticks(wide['rank'].values, cbpd_wide, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Age')
        #plt.ylim([-2.5,2])
    plt.savefig('Fig1'+fignum[j]+'_allregion.eps',  format='eps', bbox_inches='tight')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs  -0.5578 0.5458 -1.5829  0.4672  False
# 11 yrs  3 yrs   -1.862    0.0  -2.782 -0.9419   True
# 11 yrs  4 yrs   0.8328 0.5678  -0.733  2.3987  False
# 11 yrs  8 yrs   0.4456 0.6438 -0.4652  1.3564  False
# 13 yrs  3 yrs  -1.3041 0.0017 -2.2242 -0.3841   True
# 13 yrs  4 yrs   1.3907 0.1045 -0.1752  2.9565  False
# 13 yrs  8 yrs   1.0035 0.0239  0.0927  1.9143   True
#  3 yrs  4 yrs   2.6948    0.0  1.1956   4.194   True
#  3 yrs  8 yrs   2.3076    0.0  1.5169  3.0983   True
#  4 yrs  8 yrs  -0.3872 0.9485 -1.8807  1.1063  False
# ----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs  -0.3526 0.4658 -0.9505  0.2454  False
# 11 yrs  3 yrs   -2.049    0.0 -2.5856 -1.5123   True
# 11 yrs  4 yrs   1.3082 0.0015  0.3949  2.2216   True
# 11 yrs  8 yrs   0.7696 0.0013  0.2383  1.3008   True
# 13 yrs  3 yrs  -1.6964    0.0 -2.2331 -1.1598   True
# 13 yrs  4 yrs   1.6608    0.0  0.7474  2.5742   True
# 13 yrs  8 yrs   1.1221    0.0  0.5908  1.6534   True
#  3 yrs  4 yrs   3.3572    0.0  2.4827  4.2317   True
#  3 yrs  8 yrs   2.8185    0.0  2.3573  3.2798   True
#  4 yrs  8 yrs  -0.5387 0.4172 -1.4099  0.3325  False
# ----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs  -0.0989 0.9426 -0.4686  0.2709  False
# 11 yrs  3 yrs  -2.4066    0.0 -2.7385 -2.0748   True
# 11 yrs  4 yrs  -0.5318 0.0743 -1.0966   0.033  False
# 11 yrs  8 yrs   0.0729 0.9704 -0.2556  0.4014  False
# 13 yrs  3 yrs  -2.3078    0.0 -2.6396 -1.9759   True
# 13 yrs  4 yrs  -0.4329 0.2102 -0.9977  0.1319  False
# 13 yrs  8 yrs   0.1718 0.5838 -0.1567  0.5003  False
#  3 yrs  4 yrs   1.8749    0.0  1.3341  2.4156   True
#  3 yrs  8 yrs   2.4796    0.0  2.1943  2.7648   True
#  4 yrs  8 yrs   0.6047 0.0204   0.066  1.1434   True
# ----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs   0.1452 0.8194 -0.2359  0.5262  False
# 11 yrs  3 yrs  -1.8842    0.0 -2.2262 -1.5421   True
# 11 yrs  4 yrs  -0.5282 0.0926 -1.1103  0.0539  False
# 11 yrs  8 yrs   0.3619 0.0305  0.0234  0.7005   True
# 13 yrs  3 yrs  -2.0293    0.0 -2.3714 -1.6873   True
# 13 yrs  4 yrs  -0.6734 0.0156 -1.2555 -0.0913   True
# 13 yrs  8 yrs   0.2168 0.3817 -0.1218  0.5553  False
#  3 yrs  4 yrs   1.3559    0.0  0.7986  1.9132   True
#  3 yrs  8 yrs   2.2461    0.0  1.9522    2.54   True
#  4 yrs  8 yrs   0.8902 0.0003   0.335  1.4454   True
# ----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs   0.0498 0.9885 -0.2401  0.3398  False
# 11 yrs  3 yrs  -0.9292    0.0 -1.1894  -0.669   True
# 11 yrs  4 yrs   0.0475 0.9981 -0.3954  0.4903  False
# 11 yrs  8 yrs   0.3994 0.0005  0.1418   0.657   True
# 13 yrs  3 yrs   -0.979    0.0 -1.2393 -0.7188   True
# 13 yrs  4 yrs  -0.0024    1.0 -0.4453  0.4405  False
# 13 yrs  8 yrs   0.3496 0.0029   0.092  0.6072   True
#  3 yrs  4 yrs   0.9767    0.0  0.5526  1.4007   True
#  3 yrs  8 yrs   1.3286    0.0   1.105  1.5523   True
#  4 yrs  8 yrs   0.3519 0.1453 -0.0705  0.7744  False
# ----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# 11 yrs 13 yrs  -0.2619 0.7755 -0.8996 0.3758  False
# 11 yrs  3 yrs  -0.1732 0.9127 -0.7456 0.3991  False
# 11 yrs  4 yrs    0.577 0.4612 -0.3972 1.5511  False
# 11 yrs  8 yrs   0.3175 0.5172 -0.2492 0.8841  False
# 13 yrs  3 yrs   0.0886 0.9923 -0.4837  0.661  False
# 13 yrs  4 yrs   0.8388 0.1232 -0.1353  1.813  False
# 13 yrs  8 yrs   0.5793 0.0427  0.0127  1.146   True
#  3 yrs  4 yrs   0.7502 0.1711 -0.1824 1.6828  False
#  3 yrs  8 yrs   0.4907 0.0509 -0.0012 0.9826  False
#  4 yrs  8 yrs  -0.2595 0.9334 -1.1886 0.6696  False
# ---------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# 11 yrs 13 yrs  -0.2195 0.8912 -0.8978  0.4587  False
# 11 yrs  3 yrs  -1.0497 0.0001 -1.6584 -0.4409   True
# 11 yrs  4 yrs   1.0282 0.0527 -0.0079  2.0642  False
# 11 yrs  8 yrs   0.6755 0.0206  0.0729  1.2782   True
# 13 yrs  3 yrs  -0.8302 0.0028 -1.4389 -0.2214   True
# 13 yrs  4 yrs   1.2477 0.0107  0.2117  2.2838   True
# 13 yrs  8 yrs    0.895 0.0009  0.2924  1.4977   True
#  3 yrs  4 yrs   2.0779    0.0  1.0859  3.0698   True
#  3 yrs  8 yrs   1.7252    0.0   1.202  2.2484   True
#  4 yrs  8 yrs  -0.3527 0.8519 -1.3409  0.6356  False
# ----------------------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-2a53c7a0e543> in <module>
#      30         plt.xlabel('Age')
#      31         #plt.ylim([-2.5,2])
# ---> 32     plt.savefig('Fig1'+fignum[j]+'_allregion.eps',  format='eps', bbox_inches='tight')
#
# IndexError: list index out of range

# %%
wide
# Out:
#       age  column_num      donor_id  structure_id          id     PVALB  \
# 2   3 yrs  321.277778  12924.000000  10222.222222  321.277778  3.425512
# 3   4 yrs  337.000000  12298.000000  10200.333333  337.000000  6.120296
# 4   8 yrs  354.210526  12899.947368  10225.684211  354.210526  5.733101
# 0  11 yrs  374.090909  12289.000000  10220.636364  374.090909  5.287464
# 1  13 yrs  387.636364  12831.000000  10220.636364  387.636364  4.729622
#
#         SST      GAD1      GAD2      DLX1   GABARAP       VIP        sa  \
# 2  5.041407  1.961977  1.949198  1.280325  7.275117  2.800042  4.611111
# 3  8.398626  3.836850  3.305129  2.256991  8.025317  4.877910  6.000000
# 4  7.859948  4.441538  4.195300  2.608930  7.765812  4.525251  5.105263
# 0  7.090385  4.368626  3.833357  2.209518  7.448361  3.849723  5.000000
# 1  6.737826  4.269729  3.978540  2.259366  7.186477  3.630203  5.000000
#
#    rank_x  rank_y  rank_x  rank_y  rank
# 2    18.0    18.0    18.0    18.0  18.0
# 3    19.0    19.0    19.0    19.0  19.0
# 4    20.0    20.0    20.0    20.0  20.0
# 0    21.0    21.0    21.0    21.0  21.0
# 1    22.0    22.0    22.0    22.0  22.0

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()/2
    colors = ['Blues', 'Purples', 'Greens']
    for k,sets in enumerate([[0,1,6],[2,3,4,5]]):
        if k==2:
            my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
        else:
            my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
        figure = plt.figure()
        for i, marker in enumerate([markers[x] for x in sets]):
            yerr = wide_std[marker]
            x = wide_mean['sa']
            y = wide_mean[marker]
            plt.plot(x, y,color=my_palette[i])
            plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
        plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Brain regions')
        #if k ==0:
        #    plt.ylim([-1.5, 1.5])
        #else:
        #    plt.ylim([-1,1.5])
        plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
        #plt.savefig('Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
        j +=1

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()/2
    colors = ['Blues', 'Purples', 'Greens']
    for k,sets in enumerate([[0,1,6],[2,3,4,5]]):
        if k==2:
            my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
        else:
            my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
        figure = plt.figure()
        for i, marker in enumerate([markers[x] for x in sets]):
            yerr = wide_std[marker]
            x = wide_mean['sa']
            y = wide_mean[marker]
            plt.plot(x, y,color=my_palette[i])
            plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
        plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
        plt.ylabel('Marker expression (z-score)')
        plt.xlabel('Brain regions')
        #if k ==0:
        #    plt.ylim([-1.5, 1.5])
        #else:
        #    plt.ylim([-1,1.5])
        plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
        #plt.savefig('Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
        j +=1

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
wide['combined'] = wide.PVALB + wide.SST + wide.VIP
#wide['combined'] = wide.PVALB + wide.SST
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()/2
    colors = ['Blues', 'Purples', 'Greens']
    marker = 'combined'
    if k==2:
        my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
    else:
        my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
    figure = plt.figure()
    yerr = wide_std[marker]
    x = wide_mean['sa']
    y = wide_mean[marker]
    plt.plot(x, y,color=my_palette[i])
    plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
    plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
    plt.ylabel('Marker expression (z-score)')
    plt.xlabel('Brain regions')
    #if k ==0:
    #    plt.ylim([-1.5, 1.5])
    #else:
    #    plt.ylim([-1,1.5])
    plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
    #plt.savefig('Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
    j +=1
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['GAD1'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['GAD2'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['DLX1'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['GABARAP'])

# %%
fignum = ['B', 'E', 'C', 'F']
j = 0
wide = gene_columns.loc[[x for x in gene_columns.index if gene_columns.loc[x,'age'] in adults+cbpd_wide], :]
wide = wide[wide.sa>-1].sort_values('sa')
wide = wide.groupby(['sa', 'donor_name']).mean().reset_index()
#wide['combined'] = wide.PVALB + wide.SST + wide.VIP
wide['combined'] = wide.PVALB + wide.SST
ages = []
for donor in wide.donor_id:
    ages.append(gene_columns[gene_columns.donor_id==donor].age.values[0])
wide['age'] = ages
for age in [adults, cbpd_wide]:
    wide_age = wide.loc[[x for x in wide.index if wide.loc[x,'age'] in age], :]
    wide_mean = wide_age.groupby(['sa']).mean().reset_index()
    wide_std = wide_age.groupby(['sa']).sem().reset_index()/2
    colors = ['Blues', 'Purples', 'Greens']
    marker = 'combined'
    if k==2:
        my_palette = {c: sns.color_palette(colors[k], n_colors=(len(sets)+1)).as_hex()[c+1] for c in np.arange(len(sets))}
    else:
        my_palette = {c: sns.color_palette(colors[k], n_colors=len(sets)).as_hex()[c] for c in np.arange(len(sets))}
    figure = plt.figure()
    yerr = wide_std[marker]
    x = wide_mean['sa']
    y = wide_mean[marker]
    plt.plot(x, y,color=my_palette[i])
    plt.fill_between(x, y+yerr, y-yerr, alpha=0.15,color=my_palette[i]) 
    plt.xticks(x.values, child.sort_values('sa').region.values, rotation=90)
    plt.ylabel('Marker expression (z-score)')
    plt.xlabel('Brain regions')
    #if k ==0:
    #    plt.ylim([-1.5, 1.5])
    #else:
    #    plt.ylim([-1,1.5])
    plt.legend([markers[x] for x in sets], loc='upper left', bbox_to_anchor=(1, 1))
    #plt.savefig('Fig1'+fignum[j]+'.eps',  format='eps', bbox_inches='tight')
    j +=1
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['GAD1'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['GAD2'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['DLX1'])
    figure = plt.figure()
    plt.scatter(wide_mean['combined'], wide_mean['DLX2'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DLX2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-b3778fe632c4> in <module>
#      43     plt.scatter(wide_mean['combined'], wide_mean['DLX1'])
#      44     figure = plt.figure()
# ---> 45     plt.scatter(wide_mean['combined'], wide_mean['DLX2'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'DLX2'
