# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                  RNA                                        Processes.1  \
# 0    ENSG00000184349  cellular response to follicle-stimulating horm...
# 1    ENSG00000106536                                  visual perception
# 2    ENSG00000248905                            ureteric bud elongation
# 3    ENSG00000150995  regulation of postsynaptic cytosolic calcium i...
# 4    ENSG00000177301              cranial nerve structural organization
# ..               ...                                                ...
# 278  ENSG00000101470                        skeletal muscle contraction
# 279  ENSG00000152894  negative regulation of keratinocyte proliferation
# 280  ENSG00000169427                stabilization of membrane potential
# 281  ENSG00000185112                                                NaN
# 282  ENSG00000197444                   2-oxoglutarate metabolic process
#
#                                          Processes.2  \
# ...

# %%
df[df.RNA=='ENSG00000100362']
# Out:
#                 RNA                                Processes.1 Processes.2  \
# 85  ENSG00000100362  excitatory chemical synaptic transmission         NaN
#
#    Processes.3 Processes.4 Processes.5 Processes.6 Processes.7 Processes.8  \
# 85         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Processes.9  ... Processes.91 Processes.92 Processes.93 Processes.94  \
# 85         NaN  ...          NaN          NaN          NaN          NaN
#
#    Processes.95 Processes.96 Processes.97 Processes.98 Processes.99  \
# 85          NaN          NaN          NaN          NaN          NaN
#
#    Processes.100
# 85           NaN
#
# [1 rows x 101 columns]
